# %%
import mysql.connector as sql
import pandas as pd

# %%
db_connection = sql.connect(host='localhost', database='steam_database_test', user='root', password='pababb89')

# %%
df = pd.read_sql('SELECT * FROM App_ID_Info', con=db_connection)

# %%
df.head()
# Out:
#     appid                                             Title  Type  Price  \
# 0   63942  Men of War: Vietnam Special Edition Upgrade Pack   dlc   2.99
# 1  414120                                            Modbox  game  14.99
# 2  363020                                         IPackThat  game  64.99
# 3  399550                     Gladiators Online - Tiro Pack   dlc   0.99
# 4   65258  Train Simulator: Settle Carlisle Specials Add-On   dlc  29.99
#
#   Release_Date  Rating  Required_Age  Is_Multiplayer
# 0   1970-01-01      -1             0               1
# 1   2016-04-05      -1             0               0
# 2   2015-10-06      -1             0               0
# 3   2015-11-04      -1             0               0
# 4   2012-05-03      -1             0               0

# %%
df.sort_values("Rating",ascending=False)
# Out:
#         appid                                              Title   Type  \
# 326    271590                                 Grand Theft Auto V   game
# 14830      70                                          Half-Life   game
# 7490      220                                        Half-Life 2   game
# 736      7670                                          BioShock™   game
# 4915     7710                                      BioShock Demo   demo
# 85        219                                  Half-Life 2: Demo   demo
# 626       620                                           Portal 2   game
# 7048      659                                           Portal 2   game
# 6605    72850                        The Elder Scrolls V: Skyrim   game
# 12304   34440                       Sid Meier's Civilization® IV   game
# 6625     3900                       Sid Meier's Civilization® IV   game
# 13449   12110                        Grand Theft Auto: Vice City   game
# ...
